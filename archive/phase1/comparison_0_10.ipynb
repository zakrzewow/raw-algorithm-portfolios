# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from src.configspace import (
    COX_PH_CONFIGSPACE,
    GB_COX_CONFIGSPACE,
    GPR_CONFIGSPACE,
    POLY_RIDGE_CONFIGSPACE,
    RANDOM_FOREST_CONFIGSPACE,
    RANDOM_SURVIVAL_FOREST_CONFIGSPACE,
    RIDGE_CONFIGSPACE,
    SCHMEE_HAHN_QRF_CONFIGSPACE,
    SVR_CONFIGSPACE,
    TOBIT_NN_CONFIGSPACE,
    XGB_AFT_CONFIGSPACE,
    XGB_CONFIGSPACE,
)
from src.constant import (
    HO,
    PROCESSED_DATA_DIR,
    RANDOM_STATE_LIST,
    RESULTS_0_10_DIR,
    SOLVER_NUMBER_LIST,
)
from src.evaluation import evaluate_model_with_cross_validation
from src.hyperparameter_optimization import optimize_hyperparameters
from src.model import (
    SVR,
    CoxPHSurvivalAnalysis,
    GPRWithRBF,
    GradientBoostingSurvivalAnalysis,
    PolynomialRidge,
    RandomForestRegressor,
    RandomSurvivalForest,
    Ridge,
    SchmeeHahnQRF,
    TobitModel,
    XGBRegressor,
    XGBRegressorAFT,
)
from src.results import plot_line, plot_scatter, wilcoxon_df
from src.split import get_n_splits
from src.wrapper import (
    ScikitLearnWrapper,
    SkipCutOffScikitLearnWrapper,
    StandardScaledLogTransformedWrapper,
    SurvivalFunctionWrapper,
    XGBwrapper,
)

# %%
evaluations_df = pd.read_parquet(PROCESSED_DATA_DIR / "evaluations.parquet")
solvers_df = pd.read_parquet(PROCESSED_DATA_DIR / "solvers.parquet")
instances_df = pd.read_parquet(PROCESSED_DATA_DIR / "instances.parquet")

df = pd.merge(evaluations_df, solvers_df, left_on="solver_id", right_on="id").drop(columns=["id"])
df = pd.merge(df, instances_df, left_on="instance_id", right_on="id").drop(columns=["id"])
df
# Out:
#                  solver_id                       instance_id       generator  \
# 0      1251473931473582278  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 1      2289112522627003788  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 2       960932965817811220  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 3        39012066323493184  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 4       494182449327999052  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# ...                    ...                               ...             ...
# 99995  1286196444435323941            TSP/TRAIN/grid/019.tsp            grid
# 99996  1435531534300921454            TSP/TRAIN/grid/019.tsp            grid
# 99997    27607668447685341            TSP/TRAIN/grid/019.tsp            grid
# 99998  2245205590089179674            TSP/TRAIN/grid/019.tsp            grid
# 99999    85558984741464718            TSP/TRAIN/grid/019.tsp            grid
#
#          cost  ASCENT_CANDIDATES  BACKBONE_TRIALS  BACKTRACKING  \
# 0        4.74               0.95              1.0           0.0
# 1        0.02               0.15              0.0           1.0
# 2        3.72               0.20              0.0           1.0
# 3        1.52               0.60              1.0           1.0
# 4       84.44               0.90              1.0           1.0
# ...       ...                ...              ...           ...
# 99995  208.32               0.45              0.0           0.0
# 99996  300.00               0.20              1.0           0.0
# 99997    3.21               0.95              1.0           1.0
# 99998   17.23               0.65              0.0           0.0
# 99999    0.01               0.90              1.0           0.0
#
#        CANDIDATE_SET_TYPE  EXTRA_CANDIDATES  EXTRA_CANDIDATE_SET_TYPE  ...  \
# 0                     0.0               0.2                       0.0  ...
# 1                     1.0               0.4                       0.0  ...
# 2                     2.0               0.9                       0.0  ...
# 3                     2.0               0.7                       0.0  ...
# 4                     3.0               0.3                       0.0  ...
# ...                   ...               ...                       ...  ...
# 99995                 0.0               0.2                       0.0  ...
# 99996                 3.0               0.6                       0.0  ...
# 99997                 3.0               0.9                       0.0  ...
# 99998                 1.0               0.5                       0.0  ...
# 99999                 3.0               0.6                       0.0  ...
#
#        mst_dists_span  mst_dists_coef_of_var  mst_dists_sum  nnds_min  \
# 0            0.488488               1.790135       0.000225  0.000715
# 1            0.488488               1.790135       0.000225  0.000715
# 2            0.488488               1.790135       0.000225  0.000715
# 3            0.488488               1.790135       0.000225  0.000715
# 4            0.488488               1.790135       0.000225  0.000715
# ...               ...                    ...            ...       ...
# 99995        0.093952               0.462330       0.000294  0.001335
# 99996        0.093952               0.462330       0.000294  0.001335
# 99997        0.093952               0.462330       0.000294  0.001335
# 99998        0.093952               0.462330       0.000294  0.001335
# 99999        0.093952               0.462330       0.000294  0.001335
#
#        nnds_median  nnds_mean  nnds_max   nnds_sd  nnds_span  nnds_coef_of_var
# 0         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 1         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 2         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 3         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 4         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# ...            ...        ...       ...       ...        ...               ...
# 99995     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99996     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99997     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99998     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99999     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
#
# [100000 rows x 91 columns]

# %%
# from src.instance.TSP_Instance import TSP_from_index_file, set_n22_cut_off_time
# from src.constant import DATA_DIR
# import json
# train_instances = TSP_from_index_file(
#     filepath=DATA_DIR / "TSP" / "TRAIN" / "index.json",
# )
# train_instances = set_n22_cut_off_time(train_instances, reference_cut_off_time=10.0)
# instance_to_cut_off = {}
# for instance in train_instances:
#     key = instance._get_short_filepath()
#     instance_to_cut_off[key] = instance.cut_off_time
# with open("instance_to_cut_off.json", "w") as f:
#     json.dump(instance_to_cut_off, f, indent=4)

import json
with open("instance_to_cut_off.json", "r") as f:
    INSTANCE_TO_CUT_OFF = json.load(f)

(df["cost"] < df["instance_id"].map(INSTANCE_TO_CUT_OFF)).value_counts(normalize=True)
# Out:
# False    0.59602
# True     0.40398
# dtype: float64

# %%
SPLITS = get_n_splits(
    df=df,
    n=HO.N,
    instance_number=HO.INSTANCE_NUMBER,
    solver_number=HO.SOLVER_NUMBER,
    random_state=HO.RANDOM_STATE,
)

# %% [markdown]
# ### Ridge

# %%
ridge_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=Ridge,
    wrapper_cls=ScikitLearnWrapper,
    configspace=RIDGE_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "ridge_incumbent.pkl",
)

ridge_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=Ridge,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=RIDGE_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "ridge_incumbent_skip_cutoff.pkl",
)
# Out:
# [INFO][abstract_initial_design.py:147] Using 20 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 50e02f as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 0874a8 and rejected config 50e02f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 90b7a3 and rejected config 0874a8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 178a0c and rejected config 90b7a3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 89e126 and rejected config 178a0c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config fa09d2 and rejected config 89e126 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6dcdae and rejected config fa09d2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 28e117 and rejected config 6dcdae as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 933ca1 and rejected config 28e117 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config db8840 and rejected config 933ca1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 715333 and rejected config db8840 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c0f74f and rejected config 715333 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config baf3aa and rejected config c0f74f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 45b61c and rejected config baf3aa as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config da030b and rejected config 45b61c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 0998da and rejected config da030b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 1915d4 and rejected config 0998da as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][abstract_intensifier.py:595] Added config b43da6 and rejected config 1915d4 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][abstract_intensifier.py:595] Added config cfc6f2 and rejected config b43da6 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][abstract_intensifier.py:595] Added config 8c19d9 and rejected config cfc6f2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# [INFO][abstract_initial_design.py:147] Using 20 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 50e02f as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 0874a8 and rejected config 50e02f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 90b7a3 and rejected config 0874a8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 178a0c and rejected config 90b7a3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 89e126 and rejected config 178a0c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config fa09d2 and rejected config 89e126 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6dcdae and rejected config fa09d2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 28e117 and rejected config 6dcdae as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3febc0 and rejected config 28e117 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config be330e and rejected config 3febc0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 60320c and rejected config be330e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ad2587 and rejected config 60320c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 68bf8e and rejected config ad2587 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c0a107 and rejected config 68bf8e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 2da824 and rejected config c0a107 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config de93ef and rejected config 2da824 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d193a8 and rejected config de93ef as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][abstract_intensifier.py:595] Added config cfc6f2 and rejected config d193a8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0

# %% [markdown]
# ### PolynomialRidge

# %%
poly_ridge_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=PolynomialRidge,
    wrapper_cls=ScikitLearnWrapper,
    configspace=POLY_RIDGE_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "poly_ridge_incumbent.pkl",
)

poly_ridge_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=PolynomialRidge,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=POLY_RIDGE_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "poly_ridge_incumbent_skip_cutoff.pkl",
)
# Out:
# [INFO][abstract_initial_design.py:147] Using 30 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 0f550a as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config a3d22f and rejected config 0f550a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ccf945 and rejected config a3d22f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6db2ea and rejected config ccf945 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f41981 and rejected config 6db2ea as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 684350 and rejected config f41981 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8f4823 and rejected config 684350 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 856840 and rejected config 8f4823 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 25a700 and rejected config 856840 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 7aa260 and rejected config 25a700 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 730fc8 and rejected config 7aa260 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 71389b and rejected config 730fc8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config c97a47 and rejected config 71389b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 7280ab and rejected config c97a47 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# [INFO][abstract_initial_design.py:147] Using 30 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 0f550a as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config a3d22f and rejected config 0f550a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 1e50f7 and rejected config a3d22f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ccf945 and rejected config 1e50f7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6db2ea and rejected config ccf945 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c48985 and rejected config 6db2ea as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config bd9ad2 and rejected config c48985 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 02ac9a and rejected config bd9ad2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f60a1e and rejected config 02ac9a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3ede7d and rejected config f60a1e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 57f8c7 and rejected config 3ede7d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 67eca7 and rejected config 57f8c7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f47973 and rejected config 67eca7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 951028 and rejected config f47973 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config fd3ce3 and rejected config 951028 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 04ffba and rejected config fd3ce3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 08843a and rejected config 04ffba as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config e43391 and rejected config 08843a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3b326d and rejected config e43391 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config e1ac6d and rejected config 3b326d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config 7a5605 and rejected config e1ac6d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b881c5 and rejected config 7a5605 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 4a36ac and rejected config b881c5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config bf2680 and rejected config 4a36ac as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 78e3bd and rejected config bf2680 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 808e6b and rejected config 78e3bd as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][abstract_intensifier.py:595] Added config 67d8e9 and rejected config 808e6b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ac89e0 and rejected config 67d8e9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0

# %% [markdown]
# ### RandomForestRegressor

# %%
rf_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=RandomForestRegressor,
    wrapper_cls=ScikitLearnWrapper,
    configspace=RANDOM_FOREST_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "rf_incumbent.pkl",
)

rf_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=RandomForestRegressor,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=RANDOM_FOREST_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "rf_incumbent_skip_cutoff.pkl",
)
# Out:
# [INFO][abstract_initial_design.py:147] Using 70 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config f8a6b5 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 286ac7 and rejected config f8a6b5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 4ef6d2 and rejected config 286ac7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3b886b and rejected config 4ef6d2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config a19d20 and rejected config 3b886b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 0abb2a and rejected config a19d20 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3c1c6c and rejected config 0abb2a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 27563e and rejected config 3c1c6c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config eb8988 and rejected config 27563e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config d0b321 and rejected config eb8988 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b00598 and rejected config d0b321 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config fa42e9 and rejected config b00598 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 1209b9 and rejected config fa42e9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 60960e and rejected config 1209b9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config c90994 and rejected config 60960e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 163224 and rejected config c90994 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][abstract_intensifier.py:595] Added config 72514b and rejected config 163224 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 112aa3 and rejected config 72514b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 749496 and rejected config 112aa3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 00d7c4 and rejected config 749496 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c70528 and rejected config 00d7c4 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config caac9a and rejected config c70528 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 0f631e and rejected config caac9a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config a01644 and rejected config 0f631e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][abstract_intensifier.py:595] Added config a0a051 and rejected config a01644 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 4cad01 and rejected config a0a051 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 10b5bc and rejected config 4cad01 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ed1989 and rejected config 10b5bc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ada129 and rejected config ed1989 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9dccf3 and rejected config ada129 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6d88ea and rejected config 9dccf3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ee4829 and rejected config 6d88ea as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config cf1beb and rejected config ee4829 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# [INFO][abstract_initial_design.py:147] Using 70 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config f8a6b5 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 3aec21 and rejected config f8a6b5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 48189c and rejected config 3aec21 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config f12ff1 and rejected config 48189c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 48b61b and rejected config f12ff1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f2f1e4 and rejected config 48b61b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 2eea52 and rejected config f2f1e4 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 17bf66 and rejected config 2eea52 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config c37ce1 and rejected config 17bf66 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9b9b38 and rejected config c37ce1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8611a9 and rejected config 9b9b38 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 2ff264 and rejected config 8611a9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b2bf02 and rejected config 2ff264 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 89c79e and rejected config b2bf02 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0

# %% [markdown]
# ### XGBRegressor

# %%
xgb_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=XGBRegressor,
    wrapper_cls=ScikitLearnWrapper,
    configspace=XGB_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "xgb_incumbent.pkl",
)

xgb_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=XGBRegressor,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=XGB_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "xgb_incumbent_skip_cutoff.pkl",
)
# Out:
# [INFO][abstract_initial_design.py:147] Using 100 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 0610fc as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 10e0a6 and rejected config 0610fc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 830f09 and rejected config 10e0a6 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 56766b and rejected config 830f09 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config cd72fc and rejected config 56766b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 1e3b97 and rejected config cd72fc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 5993b3 and rejected config 1e3b97 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 2ea0d8 and rejected config 5993b3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3057e4 and rejected config 2ea0d8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9530dc and rejected config 3057e4 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 425de2 and rejected config 9530dc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config 192b59 and rejected config 425de2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c332f9 and rejected config 192b59 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3a8e4b and rejected config c332f9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config e9deb6 and rejected config 3a8e4b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c44d57 and rejected config e9deb6 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config fb16a8 and rejected config c44d57 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config bbee34 and rejected config fb16a8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 7e9bd1 and rejected config bbee34 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 15410f and rejected config 7e9bd1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][abstract_intensifier.py:595] Added config e44da7 and rejected config 15410f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ca362e and rejected config e44da7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][abstract_intensifier.py:595] Added config a47089 and rejected config ca362e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][abstract_intensifier.py:595] Added config 62a659 and rejected config a47089 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 920664 and rejected config 62a659 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][abstract_intensifier.py:595] Added config 796113 and rejected config 920664 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# [INFO][abstract_initial_design.py:147] Using 100 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 0610fc as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 10e0a6 and rejected config 0610fc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9b4a2b and rejected config 10e0a6 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config aa3aba and rejected config 9b4a2b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 4676f6 and rejected config aa3aba as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 376e7d and rejected config 4676f6 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 241b60 and rejected config 376e7d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8d995e and rejected config 241b60 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config e6a813 and rejected config 8d995e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config daba8e and rejected config e6a813 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3d4980 and rejected config daba8e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][abstract_intensifier.py:595] Added config 274d88 and rejected config 3d4980 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][abstract_intensifier.py:595] Added config 70664a and rejected config 274d88 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0

# %% [markdown]
# ### SVR

# %%
svr_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=SVR,
    wrapper_cls=ScikitLearnWrapper,
    configspace=SVR_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "svr_incumbent.pkl",
)

svr_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=SVR,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=SVR_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "svr_incumbent_skip_cutoff.pkl",
)
# Out:
# [INFO][abstract_initial_design.py:147] Using 60 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 383a37 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 701f00 and rejected config 383a37 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f53a91 and rejected config 701f00 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 26bdbf and rejected config f53a91 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config fa344b and rejected config 26bdbf as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 398f40 and rejected config fa344b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 7abeff and rejected config 398f40 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8f8af5 and rejected config 7abeff as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 91bb8f and rejected config 8f8af5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config fb3d0d and rejected config 91bb8f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config 466bc4 and rejected config fb3d0d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 859923 and rejected config 466bc4 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 5f19ab and rejected config 859923 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ce2639 and rejected config 5f19ab as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][abstract_intensifier.py:595] Added config 78d2d4 and rejected config ce2639 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# [INFO][abstract_initial_design.py:147] Using 60 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 383a37 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config d88a62 and rejected config 383a37 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 0b608a and rejected config d88a62 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c6d22c and rejected config 0b608a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 4372bb and rejected config c6d22c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 29f1a5 and rejected config 4372bb as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 439dd7 and rejected config 29f1a5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 42a1f4 and rejected config 439dd7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d81629 and rejected config 42a1f4 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 5e064c and rejected config d81629 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config 007c21 and rejected config 5e064c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f7acd3 and rejected config 007c21 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 404ad2 and rejected config f7acd3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config be31f3 and rejected config 404ad2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 36dca2 and rejected config be31f3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 3e1eed and rejected config 36dca2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 68c97c and rejected config 3e1eed as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config af47da and rejected config 68c97c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0

# %% [markdown]
# ### GPRWithRBF

# %%
gpr_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=GPRWithRBF,
    wrapper_cls=ScikitLearnWrapper,
    configspace=GPR_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "gpr_incumbent.pkl",
)

gpr_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=GPRWithRBF,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=GPR_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "gpr_incumbent_skip_cutoff.pkl",
)
# Out:
# [INFO][abstract_initial_design.py:147] Using 30 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 0b9b43 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 3442b9 and rejected config 0b9b43 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ec05c2 and rejected config 3442b9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d1bedb and rejected config ec05c2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 1456e2 and rejected config d1bedb as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 5891e7 and rejected config 1456e2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 011143 and rejected config 5891e7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 323aa5 and rejected config 011143 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d889f0 and rejected config 323aa5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config a0c265 and rejected config d889f0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c5e826 and rejected config a0c265 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 65a109 and rejected config c5e826 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 4e65f1 and rejected config 65a109 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config ac6327 and rejected config 4e65f1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8cf146 and rejected config ac6327 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c4b1bc and rejected config 8cf146 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8d0d59 and rejected config c4b1bc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d33234 and rejected config 8d0d59 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config cba2b7 and rejected config d33234 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c8b318 and rejected config cba2b7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 7e433f and rejected config c8b318 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 245dba and rejected config 7e433f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config aec95a and rejected config 245dba as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f94698 and rejected config aec95a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f38a71 and rejected config f94698 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 44ce6f and rejected config f38a71 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ac5cce and rejected config 44ce6f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 30245a and rejected config ac5cce as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 876cef and rejected config 30245a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 27bc5b and rejected config 876cef as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config bec7ff and rejected config 27bc5b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f4e85f and rejected config bec7ff as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 78ff41 and rejected config f4e85f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 31f3a1 and rejected config 78ff41 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9029a3 and rejected config 31f3a1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ed58ad and rejected config 9029a3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 735da0 and rejected config ed58ad as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config a976b0 and rejected config 735da0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 45ccad and rejected config a976b0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b933e8 and rejected config 45ccad as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 884b17 and rejected config b933e8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b4dec8 and rejected config 884b17 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 385516 and rejected config b4dec8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d2809c and rejected config 385516 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][abstract_intensifier.py:595] Added config e9cd26 and rejected config d2809c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][abstract_intensifier.py:595] Added config 131fe0 and rejected config e9cd26 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b498e7 and rejected config 131fe0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# [INFO][abstract_initial_design.py:147] Using 30 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 0b9b43 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 9b01d2 and rejected config 0b9b43 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f1ca9b and rejected config 9b01d2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 194b5d and rejected config f1ca9b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 780c63 and rejected config 194b5d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d3b5bd and rejected config 780c63 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 97bb01 and rejected config d3b5bd as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 897c1b and rejected config 97bb01 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 0cc332 and rejected config 897c1b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config aa5edf and rejected config 0cc332 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9bb379 and rejected config aa5edf as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 0a23b0 and rejected config 9bb379 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config 7c2ed7 and rejected config 0a23b0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c105fa and rejected config 7c2ed7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b6d341 and rejected config c105fa as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 02982e and rejected config b6d341 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c3b29b and rejected config 02982e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 4305f9 and rejected config c3b29b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config ec7af5 and rejected config 4305f9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 70da98 and rejected config ec7af5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 21262b and rejected config 70da98 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8994c9 and rejected config 21262b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 7746df and rejected config 8994c9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b6a53c and rejected config 7746df as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config c3836f and rejected config b6a53c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 84182f and rejected config c3836f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 023fea and rejected config 84182f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0

# %% [markdown]
# ### CoxPHSurvivalAnalysis

# %%
coxph_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=CoxPHSurvivalAnalysis,
    wrapper_cls=SurvivalFunctionWrapper,
    configspace=COX_PH_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "coxph_incumbent.pkl",
)
coxph_incumbent
# Out:
# [INFO][abstract_initial_design.py:147] Using 50 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 2f56c8 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 9af937 and rejected config 2f56c8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 38efba and rejected config 9af937 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 60f9f9 and rejected config 38efba as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config adb80f and rejected config 60f9f9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config af6701 and rejected config adb80f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config aac52d and rejected config af6701 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8f730f and rejected config aac52d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config f6ff3b and rejected config 8f730f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 132d34 and rejected config f6ff3b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 04a59b and rejected config 132d34 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 25d0e6 and rejected config 04a59b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 54a8a1 and rejected config 25d0e6 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 63806c and rejected config 54a8a1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 50e712 and rejected config 63806c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d0a513 and rejected config 50e712 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config 4f6d21 and rejected config d0a513 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 2dbe40 and rejected config 4f6d21 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 06c05b and rejected config 2dbe40 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c61300 and rejected config 06c05b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 71fc77 and rejected config c61300 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8ae60a and rejected config 71fc77 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 2801f4 and rejected config 8ae60a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 0bc2db and rejected config 2801f4 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config c8e024 and rejected config 0bc2db as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 7f99a9 and rejected config c8e024 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8b9f8b and rejected config 7f99a9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 62c141 and rejected config 8b9f8b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 2021a1 and rejected config 62c141 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 7f61a3 and rejected config 2021a1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 32e580 and rejected config 7f61a3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 228f39 and rejected config 32e580 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6d3ebe and rejected config 228f39 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 5aeaa1 and rejected config 6d3ebe as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][abstract_intensifier.py:595] Added config 20667d and rejected config 5aeaa1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config b29eff and rejected config 20667d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][abstract_intensifier.py:595] Added config 6284fc and rejected config b29eff as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][abstract_intensifier.py:595] Added config 1d69ff and rejected config 6284fc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config defd14 and rejected config 1d69ff as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 078b01 and rejected config defd14 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 4d1313 and rejected config 078b01 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# {'alpha': 32.7658638422622,
#  'risk_function': 'exponential',
#  'ties': 'breslow',
#  'risk_alpha': 4.9227443113732,
#  'risk_beta': 21.7552044682021,
#  'model_cls': sksurv.linear_model.coxph.CoxPHSurvivalAnalysis}

# %% [markdown]
# ### RandomSurvivalForest

# %%
rsf_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=RandomSurvivalForest,
    wrapper_cls=SurvivalFunctionWrapper,
    configspace=RANDOM_SURVIVAL_FOREST_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "rsf_incumbent.pkl",
)
rsf_incumbent
# Out:
# [INFO][abstract_initial_design.py:147] Using 90 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 20fae2 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 451903 and rejected config 20fae2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9cedd1 and rejected config 451903 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 01247f and rejected config 9cedd1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9b945d and rejected config 01247f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 2b07e9 and rejected config 9b945d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config f1704f and rejected config 2b07e9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 0295bd and rejected config f1704f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 91f29e and rejected config 0295bd as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 9ac85f and rejected config 91f29e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# {'max_depth': 12,
#  'max_features': 0.9782283013351,
#  'min_samples_leaf': 7,
#  'min_samples_split': 2,
#  'n_jobs': -1,
#  'random_state': 0,
#  'risk_function': 'linear',
#  'model_cls': sksurv.ensemble.forest.RandomSurvivalForest}

# %% [markdown]
# ### GradientBoostingSurvivalAnalysis

# %%
gb_cox_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=GradientBoostingSurvivalAnalysis,
    wrapper_cls=SurvivalFunctionWrapper,
    configspace=GB_COX_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "gb_cox_incumbent.pkl",
)
gb_cox_incumbent
# Out:
# [INFO][abstract_initial_design.py:95] Reducing the number of initial configurations from 130 to 125 (max_ratio == 0.25).
# [INFO][abstract_initial_design.py:147] Using 125 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 7e620a as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config a1191f and rejected config 7e620a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 05d4b3 and rejected config a1191f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config cbfb86 and rejected config 05d4b3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config d4a009 and rejected config cbfb86 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 1cf0f1 and rejected config d4a009 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 2b2edc and rejected config 1cf0f1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config e8de22 and rejected config 2b2edc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 0de7da and rejected config e8de22 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 416422 and rejected config 0de7da as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# {'ccp_alpha': 0.0010632091133,
#  'learning_rate': 0.0709922107583,
#  'loss': 'coxph',
#  'max_depth': 11,
#  'max_features': 0.604936786163,
#  'min_samples_leaf': 7,
#  'min_samples_split': 4,
#  'n_estimators': 623,
#  'random_state': 0,
#  'risk_function': 'par10',
#  'subsample': 0.7376034069785,
#  'model_cls': sksurv.ensemble.boosting.GradientBoostingSurvivalAnalysis}

# %% [markdown]
# ### XGBRegressorAFT

# %%
xgb_aft_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=XGBRegressorAFT,
    wrapper_cls=XGBwrapper,
    configspace=XGB_AFT_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "xgb_aft_incumbent.pkl",
)
xgb_aft_incumbent
# Out:
# [INFO][abstract_initial_design.py:95] Reducing the number of initial configurations from 140 to 125 (max_ratio == 0.25).
# [INFO][abstract_initial_design.py:147] Using 125 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 1f402b as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config e58b16 and rejected config 1f402b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 38ddd0 and rejected config e58b16 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 1b7713 and rejected config 38ddd0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 5243fc and rejected config 1b7713 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 65435c and rejected config 5243fc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config bd87d0 and rejected config 65435c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 30e542 and rejected config bd87d0 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config a3ad5c and rejected config 30e542 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 70061a and rejected config a3ad5c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config c33f24 and rejected config 70061a as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 250640 and rejected config c33f24 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 705409 and rejected config 250640 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 5fe2ae and rejected config 705409 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 0928b8 and rejected config 5fe2ae as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 40023e and rejected config 0928b8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config d7ee9d and rejected config 40023e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 227f97 and rejected config d7ee9d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# {'aft_loss_distribution': 'logistic',
#  'colsample_bytree': 0.8117356962991,
#  'eval_metric': 'aft-nloglik',
#  'gamma': 0.5353688656962,
#  'learning_rate': 0.0241392576093,
#  'max_depth': 8,
#  'min_child_weight': 1,
#  'num_boost_round': 457,
#  'objective': 'survival:aft',
#  'reg_alpha': 0.0807388347681,
#  'reg_lambda': 0.005466759938,
#  'seed': 0,
#  'subsample': 0.8740239912749,
#  'aft_loss_distribution_scale': 1.1877990509245,
#  'model_cls': src.model.XGBRegressorAFT}

# %% [markdown]
# ### SchmeeHahnQRF

# %%
sh_qrf_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=SchmeeHahnQRF,
    wrapper_cls=StandardScaledLogTransformedWrapper,
    configspace=SCHMEE_HAHN_QRF_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "sh_qrf_incumbent.pkl",
)
sh_qrf_incumbent
# Out:
# [INFO][abstract_initial_design.py:95] Reducing the number of initial configurations from 130 to 125 (max_ratio == 0.25).
# [INFO][abstract_initial_design.py:147] Using 125 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 45c66b as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 093abd and rejected config 45c66b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config a027bc and rejected config 093abd as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8a3dbb and rejected config a027bc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][abstract_intensifier.py:595] Added config 15aa0f and rejected config 8a3dbb as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 398678 and rejected config 15aa0f as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6ac272 and rejected config 398678 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config 17bce9 and rejected config 6ac272 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3ff4e1 and rejected config 17bce9 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 13fbdc and rejected config 3ff4e1 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 2fada2 and rejected config 13fbdc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 0286b3 and rejected config 2fada2 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6fcb61 and rejected config 0286b3 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 9e92fd and rejected config 6fcb61 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 6cd1bc and rejected config 9e92fd as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][abstract_intensifier.py:595] Added config 95b5f5 and rejected config 6cd1bc as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 0e6f5e and rejected config 95b5f5 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 991dc8 and rejected config 0e6f5e as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][abstract_intensifier.py:595] Added config 6e3fec and rejected config 991dc8 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 911954 and rejected config 6e3fec as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][abstract_intensifier.py:595] Added config d7cad7 and rejected config 911954 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][abstract_intensifier.py:595] Added config 78b99c and rejected config d7cad7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 3f2ee9 and rejected config 78b99c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# {'ccp_alpha': 2.9192635613669,
#  'ccp_alpha_rf': 0.0024994373033,
#  'k': 10,
#  'max_depth': 10,
#  'max_depth_rf': 12,
#  'max_features': 0.4435521963687,
#  'max_features_rf': 0.9445308000949,
#  'min_samples_leaf': 3,
#  'min_samples_leaf_rf': 7,
#  'min_samples_split': 8,
#  'min_samples_split_rf': 6,
#  'n_jobs': -1,
#  'random_state': 0,
#  'model_cls': src.model.SchmeeHahnQRF}

# %% [markdown]
# ### TobitModel

# %%
tobit_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=TobitModel,
    wrapper_cls=StandardScaledLogTransformedWrapper,
    configspace=TOBIT_NN_CONFIGSPACE,
    splits=SPLITS,
    instance_to_cut_off=INSTANCE_TO_CUT_OFF,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_0_10_DIR / "HO" / "tobit_incumbent.pkl",
)
tobit_incumbent
# Out:
# [INFO][abstract_initial_design.py:147] Using 50 initial design configurations and 1 additional configurations.
# [INFO][abstract_intensifier.py:306] Using only one seed for deterministic scenario.
# [INFO][abstract_intensifier.py:516] Added config 4f2e33 as new incumbent because there are no incumbents yet.
# [INFO][abstract_intensifier.py:595] Added config 24dcab and rejected config 4f2e33 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 8c591c and rejected config 24dcab as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 2e91db and rejected config 8c591c as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 7fba52 and rejected config 2e91db as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 91ddc7 and rejected config 7fba52 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 50 trials.
# [INFO][abstract_intensifier.py:595] Added config 12c63d and rejected config 91ddc7 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][abstract_intensifier.py:595] Added config 617e0b and rejected config 12c63d as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 100 trials.
# [INFO][smbo.py:320] Finished 150 trials.
# [INFO][abstract_intensifier.py:595] Added config c47092 and rejected config 617e0b as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 200 trials.
# [INFO][smbo.py:320] Finished 250 trials.
# [INFO][abstract_intensifier.py:595] Added config 840638 and rejected config c47092 as incumbent because it is not better than the incumbents on 1 instances:
# [INFO][smbo.py:320] Finished 300 trials.
# [INFO][smbo.py:320] Finished 350 trials.
# [INFO][smbo.py:320] Finished 400 trials.
# [INFO][smbo.py:320] Finished 450 trials.
# [INFO][smbo.py:320] Finished 500 trials.
# [INFO][smbo.py:328] Configuration budget is exhausted:
# [INFO][smbo.py:329] --- Remaining wallclock time: inf
# [INFO][smbo.py:330] --- Remaining cpu time: inf
# [INFO][smbo.py:331] --- Remaining trials: 0
# {'base_lr': 0.0001336676338,
#  'dropout': 0.429227066996,
#  'momentum': 0.6727447289219,
#  'n_epochs': 219,
#  'scheduler_step_size_up': 867,
#  'model_cls': src.model.TobitModel}

# %% [markdown]
# ## Comparison

# %%
model_info_list = [
    # include cut-off
    {
        "wrapper": ScikitLearnWrapper(**ridge_incumbent),
        "name": "Ridge Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**poly_ridge_incumbent),
        "name": "Polynomial Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**svr_incumbent),
        "name": "Support Vector Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**gpr_incumbent),
        "name": "Gaussian Process Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**rf_incumbent),
        "name": "Random Forest"
    },
    {
        "wrapper": ScikitLearnWrapper(**xgb_incumbent),
        "name": "XGBoost"
    },
    # skip cut-off
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**ridge_incumbent_skip_cutoff),
        "name": "Ridge Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**poly_ridge_incumbent_skip_cutoff),
        "name": "Polynomial Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**svr_incumbent_skip_cutoff),
        "name": "Support Vector Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**gpr_incumbent_skip_cutoff),
        "name": "Gaussian Process Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**rf_incumbent_skip_cutoff),
        "name": "Random Forest (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**xgb_incumbent_skip_cutoff),
        "name": "XGBoost (skip cut-off)"
    },
    # survival models
    {
        "wrapper": SurvivalFunctionWrapper(**coxph_incumbent),
        "name": "Cox PH"
    },
    {
        "wrapper": SurvivalFunctionWrapper(**rsf_incumbent),
        "name": "Random Survival Forest"
    },
    {
        "wrapper": SurvivalFunctionWrapper(**gb_cox_incumbent),
        "name": "Gradient Boosting Cox"
    },
    {
        "wrapper": XGBwrapper(**xgb_aft_incumbent),
        "name": "XGBoost AFT"
    },
    {
        "wrapper": StandardScaledLogTransformedWrapper(**sh_qrf_incumbent),
        "name": "S&H QRF"
    },
    {
        "wrapper": StandardScaledLogTransformedWrapper(**tobit_incumbent),
        "name": "NN Tobit"
    },
]
 
total_iterations = len(RANDOM_STATE_LIST) * len(SOLVER_NUMBER_LIST) * len(model_info_list)
pbar = tqdm(total=total_iterations, desc="Evaluating models")

records = []

for random_state in RANDOM_STATE_LIST:
    for solver_number in SOLVER_NUMBER_LIST:
        pbar.set_description(f"RS={random_state}, Solvers={solver_number}")
        splits = get_n_splits(
            df,
            n=5,
            instance_number=10,
            solver_number=solver_number,
            random_state=random_state,
        )
        for model_info in model_info_list:
            pbar.set_postfix(model=model_info["name"])

            result = evaluate_model_with_cross_validation(
                df,
                wrapper=model_info["wrapper"],
                splits=splits,
                random_state=random_state,
                instance_to_cut_off=INSTANCE_TO_CUT_OFF,
            )
            result["random_state"] = random_state
            result["solver_number"] = solver_number
            result["name"] = model_info["name"]
            records.append(result)
            pbar.update(1)

pbar.close()
result_df = pd.DataFrame(records)
result_df.to_pickle(RESULTS_0_10_DIR / "results.gzip", compression="gzip")

result_df = pd.read_pickle(RESULTS_0_10_DIR / "results.gzip", compression="gzip")
# Out:
# Evaluating models:   0%|          | 0/4320 [00:00<?, ?it/s]

# %%
plot_df = result_df.loc[(result_df["random_state"] == 1) & (result_df["solver_number"] == 300)].iloc[:6].reset_index(drop=True)

fig, axs = plot_scatter(plot_df)
# plt.savefig("fig.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plot_df = result_df.loc[(result_df["random_state"] == 1) & (result_df["solver_number"] == 300)].iloc[6:12].reset_index(drop=True)

fig, axs = plot_scatter(plot_df)
# plt.savefig("fig.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plot_df = result_df.loc[(result_df["random_state"] == 1) & (result_df["solver_number"] == 300)].iloc[12:].reset_index(drop=True)

fig, axs = plot_scatter(plot_df)
# plt.savefig("fig.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
fig, ax = plot_line(
    result_df.loc[
        result_df["name"].isin(
            [
                "Cox PH",
                "Random Survival Forest",
                "Gradient Boosting Cox",
                "XGBoost AFT",
                "S&H QRF",
                "NN Tobit",
            ]
        )
    ]
)

# plt.savefig("fig.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
styled_result = wilcoxon_df(result_df, model_info_list)
styled_result
