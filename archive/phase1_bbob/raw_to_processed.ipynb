# %%
import json
import sys
from pathlib import Path

import numpy as np
import pandas as pd

current_dir = Path.cwd()
parent_dir = str(current_dir.parent.parent)
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)


from src.constant import DATA_DIR, MAIN_DIR
from src.database.db import DB

PHASE1_DIR = MAIN_DIR / "archive" / "phase1_bbob" 
RAW_DIR = PHASE1_DIR / "raw"
PROCESSED_DIR = PHASE1_DIR / "processed"
FEATURES_PATH = DATA_DIR / "BBOB" / "features.json"

# %%
with open(FEATURES_PATH, "r") as f:
    features = json.load(f)

features_df = pd.DataFrame([{"id": k, **v["result"]} for k, v in features.items()])

# %%
instances_frames = []
evaluations_frames = []

for db_path in RAW_DIR.glob("*.db"):
    print(db_path)

    db = DB(db_path)
    
    instances_df = db.get_instances()
    instances_frames.append(instances_df)

    evaluations_df = db.get_evaluations().drop(columns=["id"])
    evaluations_df["cost"] = np.where(evaluations_df["cost"] == 3000.0, 300.0, evaluations_df["cost"])
    evaluations_frames.append(evaluations_df)

db.get_solvers().to_parquet(PROCESSED_DIR / "solvers.parquet", index=False)

instances_df = pd.concat(instances_frames, ignore_index=True)
instances_df = pd.merge(instances_df, features_df, on="id", how="left")
instances_df.to_parquet(PROCESSED_DIR / "instances.parquet", index=False)

evaluations_df = pd.concat(evaluations_frames, ignore_index=True)
evaluations_df.to_parquet(PROCESSED_DIR / "evaluations.parquet", index=False)
# Out:
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128432.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128459.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128463.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128464.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128465.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128466.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128468.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128485.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128486.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128487.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128488.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128489.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128490.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128491.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128492.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128493.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128494.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128495.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128496.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128497.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128498.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128499.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128500.db
# C:\Users\gzakrzewski\Documents\projects\raw-algorithm-portfolios\archive\phase1_bbob\raw\run-phase1-dataset-baseline--25-1128501.db

# %%
evaluations_df = pd.read_parquet(PROCESSED_DIR / "evaluations.parquet")
solvers_df = pd.read_parquet(PROCESSED_DIR / "solvers.parquet")
instances_df = pd.read_parquet(PROCESSED_DIR / "instances.parquet")

df = pd.merge(evaluations_df, solvers_df, left_on="solver_id", right_on="id").drop(columns=["id"])
df = pd.merge(df, instances_df, left_on="instance_id", right_on="id").drop(columns=["id"])
df
# Out:
#                   solver_id          instance_id        cost  ALGORITHM  \
# 0        410950163550714701  1459556901948702861    0.364175        0.0
# 1       1743092914995070369  1459556901948702861    0.398162        0.0
# 2       2283111023303066572  1459556901948702861    0.055367        1.0
# 3       2253826169615980878  1459556901948702861    0.808347        1.0
# 4       1589992703076004730  1459556901948702861    0.572030        1.0
# ...                     ...                  ...         ...        ...
# 119995  1090844655874379195  1903964392399407975  300.000000        0.0
# 119996   686048789577017900  1903964392399407975  300.000000        0.0
# 119997   243020324673513847  1903964392399407975  300.000000        0.0
# 119998   708619547354767275  1903964392399407975  300.000000        0.0
# 119999   396791986407096231  1903964392399407975  300.000000        0.0
#
#         CMA_ELITIST  CMA_POPSIZE  CMA_POPSIZE_FACTOR  CMA_RANDOM_INIT  \
# 0               1.0     0.955556            0.410492              1.0
# 1               1.0     0.600000            0.246063              1.0
# 2               0.0     0.244444            0.426904              1.0
# 3               1.0     0.111111            0.118728              1.0
# 4               1.0     0.700000            0.884952              1.0
# ...             ...          ...                 ...              ...
# 119995          1.0     0.222222            0.604851              0.0
# 119996          0.0     0.744444            0.570018              0.0
# 119997          1.0     0.644444            0.531420              0.0
# 119998          0.0     0.233333            0.384026              0.0
# 119999          1.0     1.000000            0.586070              0.0
#
#         CMA_SCALE  DE_CROSSOVER  ...  pca_expl_var_PC1_cor_x  \
# 0        0.972919      0.081101  ...                0.530700
# 1        0.447144      0.449083  ...                0.530700
# 2        0.406922      0.772266  ...                0.530700
# 3        0.916723      0.842342  ...                0.530700
# 4        0.751022      0.878372  ...                0.530700
# ...           ...           ...  ...                     ...
# 119995   0.259828      0.415285  ...                0.062206
# 119996   0.793826      0.983013  ...                0.062206
# 119997   0.071196      0.581472  ...                0.062206
# 119998   0.714490      0.829189  ...                0.062206
# 119999   0.544160      0.658862  ...                0.062206
#
#         pca_expl_var_PC1_cov_init  pca_expl_var_PC1_cor_init  \
# 0                        0.919870                   0.522955
# 1                        0.919870                   0.522955
# 2                        0.919870                   0.522955
# 3                        0.919870                   0.522955
# 4                        0.919870                   0.522955
# ...                           ...                        ...
# 119995                   0.990413                   0.067438
# 119996                   0.990413                   0.067438
# 119997                   0.990413                   0.067438
# 119998                   0.990413                   0.067438
# 119999                   0.990413                   0.067438
#
#         pca_costs_runtime  ic_h_max  ic_eps_s  ic_eps_max  ic_eps_ratio  \
# 0                0.006267  0.745011  1.106106    2.633336      0.635636
# 1                0.006267  0.745011  1.106106    2.633336      0.635636
# 2                0.006267  0.745011  1.106106    2.633336      0.635636
# 3                0.006267  0.745011  1.106106    2.633336      0.635636
# 4                0.006267  0.745011  1.106106    2.633336      0.635636
# ...                   ...       ...       ...         ...           ...
# 119995           0.269816  0.868371  1.546547    5.568596      0.995996
# 119996           0.269816  0.868371  1.546547    5.568596      0.995996
# 119997           0.269816  0.868371  1.546547    5.568596      0.995996
# 119998           0.269816  0.868371  1.546547    5.568596      0.995996
# 119999           0.269816  0.868371  1.546547    5.568596      0.995996
#
#            ic_m0  ic_costs_runtime
# 0       0.392857          0.717704
# 1       0.392857          0.717704
# 2       0.392857          0.717704
# 3       0.392857          0.717704
# 4       0.392857          0.717704
# ...          ...               ...
# 119995  0.627756         21.302308
# 119996  0.627756         21.302308
# 119997  0.627756         21.302308
# 119998  0.627756         21.302308
# 119999  0.627756         21.302308
#
# [120000 rows x 85 columns]

# %%
df.groupby("dimension")["cost"].describe()
# Out:
#              count        mean         std       min         25%         50%  \
# dimension
# 2          24000.0   77.387730  128.857061  0.005787    0.607542    1.566070
# 3          24000.0  135.906009  147.036095  0.006001    1.349006   12.922658
# 5          24000.0  181.805552  144.454758  0.008303    3.195017  300.000000
# 10         24000.0  215.480567  132.872267  0.012826   11.629091  300.000000
# 20         24000.0  232.103117  122.403844  0.022462  300.000000  300.000000
#
#              75%    max
# dimension
# 2          300.0  300.0
# 3          300.0  300.0
# 5          300.0  300.0
# 10         300.0  300.0
# 20         300.0  300.0

# %%
df.groupby("function_index")["cost"].describe().style.background_gradient(cmap="coolwarm", axis=0).format(precision=2)
# Out:
# <style type="text/css">
{
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_4fe71_row6_col3, #T_4fe71_row11_col4, #T_4fe71_row12_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_4fe71_row7_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_4fe71_row7_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_4fe71_row7_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_4fe71_row7_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4fe71_row8_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_4fe71_row8_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_4fe71_row8_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4fe71_row8_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_4fe71_row9_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_4fe71_row9_col2, #T_4fe71_row10_col2, #T_4fe71_row13_col2, #T_4fe71_row15_col2 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_4fe71_row9_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_4fe71_row10_col1, #T_4fe71_row13_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_4fe71_row10_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_4fe71_row11_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_4fe71_row11_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_4fe71_row12_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_4fe71_row12_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_4fe71_row12_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_4fe71_row13_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_4fe71_row14_col1, #T_4fe71_row22_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_4fe71_row14_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_4fe71_row14_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_4fe71_row14_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_4fe71_row15_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_4fe71_row15_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4fe71_row16_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_4fe71_row16_col2 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_4fe71_row16_col3 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_4fe71_row16_col4, #T_4fe71_row20_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4fe71_row17_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_4fe71_row17_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_4fe71_row17_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_4fe71_row17_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4fe71_row18_col1 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_4fe71_row18_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_4fe71_row18_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_4fe71_row18_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4fe71_row19_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_4fe71_row19_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_4fe71_row19_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_4fe71_row19_col4, #T_4fe71_row20_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4fe71_row20_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_4fe71_row20_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_4fe71_row21_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_4fe71_row21_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_4fe71_row22_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_4fe71_row22_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4fe71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fe71_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_4fe71_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_4fe71_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_4fe71_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_4fe71_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_4fe71_level0_col5" class="c

# %%
(df["cost"] == 300).value_counts(normalize=True)
# Out:
# True     0.5541
# False    0.4459
# Name: cost, dtype: float64

# %%
thresholds = np.linspace(0.05, 20.0, 400)
for dimension in df["dimension"].unique():
    dimension_df = df.loc[~df["function_index"].isin([3, 4, 15, 18, 19, 20, 22, 23, 24])].loc[df["dimension"] == dimension]
    for t in thresholds:
        cutoff_ratio = (dimension_df["cost"] > t).mean()
        if cutoff_ratio <= 0.6:
            print(f"Dimension: {dimension}, Threshold: {t:.2f}, Cutoff Ratio: {cutoff_ratio:.4f}")
            break
# Out:
# Dimension: 2, Threshold: 0.75, Cutoff Ratio: 0.5967
# Dimension: 3, Threshold: 1.55, Cutoff Ratio: 0.5997
# Dimension: 5, Threshold: 4.30, Cutoff Ratio: 0.5993

# %%
(3/2) ** 3 * 0.75
# Out:
# 2.53125

# %%
df.loc[~df["function_index"].isin([3, 4, 15, 18, 19, 20, 22, 23, 24])].assign(is_cutoff=lambda x: x["cost"] == 300).pivot_table(index="function_index", columns="dimension", values="is_cutoff").style.background_gradient(cmap="coolwarm", axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_fae14_row0_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fae14_row0_col1, #T_fae14_row2_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_fae14_row0_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_fae14_row0_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_fae14_row0_col4, #T_fae14_row4_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_fae14_row1_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_fae14_row1_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_fae14_row1_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_fae14_row1_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_fae14_row1_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_fae14_row2_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_fae14_row2_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_fae14_row2_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_fae14_row2_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_fae14_row3_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_fae14_row3_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_fae14_row3_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_fae14_row3_col3, #T_fae14_row7_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_fae14_row3_col4, #T_fae14_row4_col3, #T_fae14_row9_col2 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_fae14_row4_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_fae14_row4_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_fae14_row4_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_fae14_row5_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_fae14_row5_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_fae14_row5_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_fae14_row5_col3 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_fae14_row5_col4, #T_fae14_row13_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_fae14_row6_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_fae14_row6_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_fae14_row6_col2 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_fae14_row6_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_fae14_row6_col4, #T_fae14_row7_col3, #T_fae14_row7_col4, #T_fae14_row8_col3, #T_fae14_row8_col4, #T_fae14_row9_col3, #T_fae14_row9_col4, #T_fae14_row10_col3, #T_fae14_row11_col3, #T_fae14_row11_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_fae14_row7_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_fae14_row7_col2, #T_fae14_row11_col2 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_fae14_row8_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_fae14_row8_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_fae14_row8_col2, #T_fae14_row9_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_fae14_row9_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_fae14_row10_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_fae14_row10_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_fae14_row10_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_fae14_row10_col4, #T_fae14_row14_col4 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_fae14_row11_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_fae14_row11_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_fae14_row12_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_fae14_row12_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_fae14_row12_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_fae14_row12_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_fae14_row12_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fae14_row13_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_fae14_row13_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_fae14_row13_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_fae14_row13_col4, #T_fae14_row14_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_fae14_row14_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_fae14_row14_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_fae14_row14_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fae14">
#   <thead>
#     <tr>
#       <th class="index_name level0" >dimension</th>
#       <th id="T_fae14_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_fae14_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_fae14_level0_col2" class="col_heading level0 col2" >5</th>
#       <th id="T_fae14_level0_col3" class="col_heading level0 col3" >10</th>
#       <th id="T_fae14_level0_col4" class="col_heading level0 col4" >20</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >function_index</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fae14_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fae14_row0_col0" class="data row0 col0" >0.05</td>
#       <td id="T_fae14_row0_col1" class="data row0 col1" >0.08</td>
#       <td id="T_fae14_row0_col2" class="data row0 col2" >0.17</td>
#       <td id="T_fae14_row0_col3" class="data row0 col3" >0.36</td>
#       <td id="T_fae14_row0_col4" class="data row0 col4" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_fae14_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fae14_row1_col0" class="data row1 col0" >0.11</td>
#       <td id="T_fae14_row1_col1" class="data row1 col1" >0.15</td>
#       <td id="T_fae14_row1_col2" class="data row1 col2" >0.23</td>
#       <td id="T_fae14_row1_col3" class="data row1 col3" >0.39</td>
#       <td id="T_fae14_row1_col4" class="data row1 col4" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_fae14_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_fae14_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_fae14_row2_col1" class="data row2 col1" >0.08</td>
#       <td id="T_fae14_row2_col2" class="data row2 col2" >0.08</td>
#       <td id="T_fae14_row2_col3" class="data row2 col3" >0.10</td>
#       <td id="T_fae14_row2_col4" class="data row2 col4" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_fae14_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_fae14_row3_col0" class="data row3 col0" >0.26</td>
#       <td id="T_fae14_row3_col1" class="data row3 col1" >0.25</td>
#       <td id="T_fae14_row3_col2" class="data row3 col2" >0.41</td>
#       <td id="T_fae14_row3_col3" class="data row3 col3" >0.53</td>
#       <td id="T_fae14_row3_col4" class="data row3 col4" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_fae14_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_fae14_row4_col0" class="data row4 col0" >0.06</td>
#       <td id="T_fae14_row4_col1" class="data row4 col1" >0.10</td>
#       <td id="T_fae14_row4_col2" class="data row4 col2" >0.45</td>
#       <td id="T_fae14_row4_col3" class="data row4 col3" >0.64</td>
#       <td id="T_fae14_row4_col4" class="data row4 col4" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_fae14_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_fae14_row5_col0" class="data row5 col0" >0.15</td>
#       <td id="T_fae14_row5_col1" class="data row5 col1" >0.32</td>
#       <td id="T_fae14_row5_col2" class="data row5 col2" >0.57</td>
#       <td id="T_fae14_row5_col3" class="data row5 col3" >0.63</td>
#       <td id="T_fae14_row5_col4" class="data row5 col4" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_fae14_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_fae14_row6_col0" class="data row6 col0" >0.13</td>
#       <td id="T_fae14_row6_col1" class="data row6 col1" >0.30</td>
#       <td id="T_fae14_row6_col2" class="data row6 col2" >0.61</t
