# %%
import numpy as np
import pandas as pd

from src.constant import DATA_DIR, DATABASE_DIR
from src.database import DB
from src.database.queries import *
from src.instance.InstanceList import InstanceList
from src.instance.TSP_Instance import TSP_from_index_file
from src.solver.TSP_LKH_Solver import TSP_LKH_Solver

# %%
generators = [
    "cluster_netgen",
    "compression",
    "expansion",
    "explosion",
    "grid",
    "cluster",
    "implosion",
    "linearprojection",
    "rotation",
    "uniform_portgen",
]

test_instances = TSP_from_index_file(filepath=DATA_DIR / "TSP" / "TEST_600" / "index.json")

id_to_generator_name = {
    instance.id(): instance.filepath.parts[-2] for instance in test_instances
}

id_to_name = {
    instance.id(): instance.filepath.parts[-1] for instance in test_instances
}

# %%
def agg_prefix(prefix):
    def agg_cost(x):
        count = x.shape[0]
        x = x[x < TSP_LKH_Solver.MAX_COST]
        x = x.sort_values()
        idx = count // 2
        if x.shape[0] <= idx:
            return x.iloc[-1]
        return x.iloc[idx]

    db_path = list(DATABASE_DIR.glob(f"{prefix}-*.db"))[0]
    db = DB(db_path)
    results = pd.read_sql_query("SELECT * FROM results", db._conn)
    results["run_id"] = results["prefix"].str.split(";", expand=True)[0]
    runs = results["run_id"].unique()

    frames = []
    for run in runs:
        results_run = results[results["run_id"] == run]

        series = (
            results_run
            .groupby(["instance_id", "prefix"])["cost"]
            .min()
            .reset_index()
            .groupby("instance_id")["cost"]
            .agg(agg_cost)
        )
        frames.append(series)

    df = (
        pd.concat(frames, axis=1)
        .mean(axis=1)
        .round(3)
        .to_frame()
    )
    df["generator"] = df.index.map(id_to_generator_name)
    df["name"] = df.index.map(id_to_name)
    df = df.pivot_table(index="generator", columns="name", values=0).loc[generators, :]
    return df

n = 500
from_ = 400
plain = agg_prefix(f"run-plain-{n}-{from_}")
sur25 = agg_prefix(f"run-{n}-sur-25-{from_}")
sur50 = agg_prefix(f"run-{n}-sur-50-{from_}")
sur75 = agg_prefix(f"run-{n}-sur-75-{from_}")

plain = plain.assign(generator=f"plain-{n}").set_index("generator", append=True)
sur25 = sur25.assign(generator="surrogate-25").set_index("generator", append=True)
sur50 = sur50.assign(generator="surrogate-50").set_index("generator", append=True)
sur75 = sur75.assign(generator="surrogate-75").set_index("generator", append=True)

# %%
df = pd.concat([plain, sur25, sur50, sur75], axis=0).sort_index(level=0).loc[generators]   
df["mean"] = df.mean(axis=1)

# %%
df.style.background_gradient(cmap="Reds", vmin=0, vmax=5).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_30a21_row0_col0, #T_30a21_row1_col4, #T_30a21_row7_col4, #T_30a21_row15_col5, #T_30a21_row20_col5, #T_30a21_row25_col3, #T_30a21_row32_col1, #T_30a21_row32_col2, #T_30a21_row33_col1, #T_30a21_row35_col3, #T_30a21_row39_col5 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_30a21_row0_col1 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_30a21_row0_col2, #T_30a21_row10_col4, #T_30a21_row35_col5 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_30a21_row0_col3, #T_30a21_row1_col0, #T_30a21_row14_col4, #T_30a21_row24_col5 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_30a21_row0_col4, #T_30a21_row4_col1, #T_30a21_row4_col4, #T_30a21_row4_col5, #T_30a21_row5_col5, #T_30a21_row9_col0, #T_30a21_row10_col0, #T_30a21_row19_col5 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_30a21_row0_col5, #T_30a21_row26_col3 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_30a21_row1_col1 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_30a21_row1_col2, #T_30a21_row17_col2 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_30a21_row1_col3, #T_30a21_row2_col3, #T_30a21_row3_col0, #T_30a21_row26_col5, #T_30a21_row33_col3, #T_30a21_row36_col4 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_30a21_row1_col5, #T_30a21_row19_col2 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_30a21_row2_col0, #T_30a21_row6_col4, #T_30a21_row14_col5, #T_30a21_row34_col4, #T_30a21_row38_col5 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_30a21_row2_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_30a21_row2_col2 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_30a21_row2_col4, #T_30a21_row6_col1, #T_30a21_row9_col2, #T_30a21_row19_col4, #T_30a21_row22_col3, #T_30a21_row26_col0, #T_30a21_row28_col2, #T_30a21_row31_col2, #T_30a21_row39_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_30a21_row2_col5 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_30a21_row3_col1 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_30a21_row3_col2 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_30a21_row3_col3, #T_30a21_row20_col4 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_30a21_row3_col4, #T_30a21_row11_col3, #T_30a21_row20_col1, #T_30a21_row32_col5 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_30a21_row3_col5, #T_30a21_row9_col1, #T_30a21_row9_col4 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_30a21_row4_col0, #T_30a21_row15_col0, #T_30a21_row31_col3 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_30a21_row4_col2, #T_30a21_row5_col3, #T_30a21_row6_col2, #T_30a21_row8_col2, #T_30a21_row21_col5, #T_30a21_row33_col5, #T_30a21_row36_col3, #T_30a21_row38_col0, #T_30a21_row39_col3 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_30a21_row4_col3, #T_30a21_row22_col0 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_30a21_row5_col0, #T_30a21_row13_col0, #T_30a21_row14_col0, #T_30a21_row17_col3, #T_30a21_row30_col3, #T_30a21_row37_col2 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_30a21_row5_col1, #T_30a21_row12_col5, #T_30a21_row18_col4, #T_30a21_row18_col5 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_30a21_row5_col2, #T_30a21_row5_col4, #T_30a21_row7_col1, #T_30a21_row23_col0, #T_30a21_row24_col0, #T_30a21_row31_col0, #T_30a21_row33_col0, #T_30a21_row35_col1, #T_30a21_row36_col0, #T_30a21_row36_col5, #T_30a21_row38_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_30a21_row6_col0, #T_30a21_row13_col1, #T_30a21_row29_col0, #T_30a21_row29_col1, #T_30a21_row30_col0, #T_30a21_row38_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_30a21_row6_col3, #T_30a21_row11_col0, #T_30a21_row27_col0, #T_30a21_row28_col4 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_30a21_row6_col5, #T_30a21_row10_col2, #T_30a21_row11_col2, #T_30a21_row22_col1, #T_30a21_row32_col3, #T_30a21_row37_col4 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_30a21_row7_col0, #T_30a21_row20_col3, #T_30a21_row23_col2, #T_30a21_row34_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_30a21_row7_col2, #T_30a21_row23_col1, #T_30a21_row38_col4 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_30a21_row7_col3, #T_30a21_row8_col4 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_30a21_row7_col5, #T_30a21_row12_col2, #T_30a21_row12_col4, #T_30a21_row13_col2, #T_30a21_row16_col2, #T_30a21_row34_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_30a21_row8_col0, #T_30a21_row16_col1, #T_30a21_row28_col5, #T_30a21_row30_col2, #T_30a21_row35_col4, #T_30a21_row38_col3 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_30a21_row8_col1 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_30a21_row8_col3, #T_30a21_row14_col3, #T_30a21_row16_col5, #T_30a21_row18_col1, #T_30a21_row21_col3, #T_30a21_row30_col5, #T_30a21_row31_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_30a21_row8_col5, #T_30a21_row30_col4, #T_30a21_row31_col4, #T_30a21_row32_col0, #T_30a21_row34_col3 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_30a21_row9_col3, #T_30a21_row22_col2, #T_30a21_row26_col1, #T_30a21_row36_col2, #T_30a21_row37_col0, #T_30a21_row37_col5 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_30a21_row9_col5, #T_30a21_row22_col5, #T_30a21_row29_col4, #T_30a21_row34_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_30a21_row10_col1 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_30a21_row10_col3, #T_30a21_row27_col1, #T_30a21_row29_col2, #T_30a21_row29_col5 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_30a21_row10_col5, #T_30a21_row34_col5 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_30a21_row11_col1 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_30a21_row11_col4, #T_30a21_row27_col5 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_30a21_row11_col5 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_30a21_row12_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_30a21_row12_col1, #T_30a21_row13_col3, #T_30a21_row21_col2, #T_30a21_row26_col2, #T_30a21_row27_col2, #T_30a21_row28_col0, #T_30a21_row30_col1, #T_30a21_row37_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_30a21_row12_col3, #T_30a21_row16_col3, #T_30a21_row24_col2, #T_30a21_row25_col2 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_30a21_row13_col4, #T_30a21_row17_col5, #T_30a21_row19_col1, #T_30a21_row25_col0, #T_30a21_row31_col5, #T_30a21_row32_col4, #T_30a21_row33_col2 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_30a21_row13_col5, #T_30a21_row16_col4, #T_30a21_row20_col0, #T_30a21_row20_col2, #T_30a21_row21_col0 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_30a21_row14_col1, #T_30a21_row25_col1, #T_30a21_row33_col4, #T_30a21_row37_col3, #T_30a21_row39_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_30a21_row14_col2 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_30a21_row15_col1, #T_30a21_row17_col1, #T_30a21_row17_col4, #T_30a21_row24_col1, #T_30a21_row28_col1, #T_30a21_row36_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_30a21_row15_col2, #T_30a21_row21_col4, #T_30a21_row39_col4 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_30a21_row15_col3, #T_30a21_row15_col4 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_30a21_row16_col0, #T_30a21_row18_col0, #T_30a21_row19_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_30a21_row17_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_30a21_row18_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_30a21_row18_col3, #T_30a21_row28_col3, #T_30a21_row29_col3 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_30a21_row19_col3 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_30a21_row21_col1, #T_30a21_row24_col3, #T_30a21_row39_col0 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_30a21_row22_col4 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_30a21_row23_col3, #T_30a21_row23_col5, #T_30a21_row27_col3 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_30a21_row23

# %%
plain_total_mean = plain.mean(axis=1).mean(axis=0)
sur25_total_mean = sur25.mean(axis=1).mean(axis=0)
sur50_total_mean = sur50.mean(axis=1).mean(axis=0)
sur75_total_mean = sur75.mean(axis=1).mean(axis=0)
print(f"{plain_total_mean=:.3f}")
print(f"{sur25_total_mean=:.3f}")
print(f"{sur50_total_mean=:.3f}")
print(f"{sur75_total_mean=:.3f}")
# Out:
# plain_total_mean=0.659
# sur25_total_mean=0.677
# sur50_total_mean=0.702
# sur75_total_mean=0.879

# %%
plain_training = plain.iloc[:5].mean(axis=1).mean(axis=0)
sur25_training = sur25.iloc[:5].mean(axis=1).mean(axis=0)
sur50_training = sur50.iloc[:5].mean(axis=1).mean(axis=0)
sur75_training = sur75.iloc[:5].mean(axis=1).mean(axis=0)

plain_not_training = plain.iloc[5:].mean(axis=1).mean(axis=0)
sur25_not_training = sur25.iloc[5:].mean(axis=1).mean(axis=0)
sur50_not_training = sur50.iloc[5:].mean(axis=1).mean(axis=0)
sur75_not_training = sur75.iloc[5:].mean(axis=1).mean(axis=0)

print(f"{plain_training=:.3f}", f"{plain_not_training=:.3f}")
print(f"{sur25_training=:.3f}", f"{sur25_not_training=:.3f}")
print(f"{sur50_training=:.3f}", f"{sur50_not_training=:.3f}")
print(f"{sur75_training=:.3f}", f"{sur75_not_training=:.3f}")
# Out:
# plain_training=0.641 plain_not_training=0.676
# sur25_training=0.683 sur25_not_training=0.671
# sur50_training=0.687 sur50_not_training=0.716
# sur75_training=0.855 sur75_not_training=0.903

# %%
# 
df.to_excel("tmp.xlsx")
